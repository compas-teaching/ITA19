# %% [markdown]
# ## Dot product

# %% [markdown]
# Intuitively, the dot product can be understood as a way to measure how much two vectors go in the same direction.

# %%
from compas.geometry import Vector
from compas_plotters import Plotter

# %%
u = Vector(1, 0, 0)
v = Vector(1, 1, 0)

# %%
u.dot(v)
# Out:
# 1.0

# %%
plotter = Plotter(figsize=(10, 7))

plotter.draw_lines([
    {'start': Point(0, 0, 0), 'end': u, 'width': 2.0},
    {'start': Point(0, 0, 0), 'end': v, 'width': 2.0}])

plotter.show()

# %% [markdown]
# ## Cross product

# %% [markdown]
# The cross product of two vectors $\mathbf{a}$ and $\mathbf{b}$ is a third vector that is perpendicular to the plane defined by $\mathbf{a}$ and $\mathbf{b}$

# %% [markdown]
# $$
# \mathbf{a}\times\mathbf{b} = [a_y b_z - b_y a_z, \, a_z b_x - b_z a_x, \, a_x b_y - b_x a_y]
# $$

# %%
# The length of the c vector is $$||\mathbf{a}\times\mathbf{b}|| = ||\mathbf{a}|| \, ||\mathbf{b}|| \, sin(\alpha)$$ with $\alpha$ the angle between $\mathbf{a}$ and $\mathbf{b}$.
